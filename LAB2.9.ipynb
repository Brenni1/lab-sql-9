# %% [markdown]
# #Imports/Basics

# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

import getpass  

password = getpass.getpass()
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)

# %% [markdown]
# #1

# %%
query = "SELECT COUNT(DISTINCT(last_name)) FROM actor;"
data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    COUNT(DISTINCT(last_name))
# 0                         121

# %% [markdown]
# 2#

# %%
query = '''SELECT
	*,
    monthname(rental_date) AS 'month',
	weekday(rental_date) AS 'weekday',
    CASE
	WHEN weekday(rental_date) <=5 then 'Workday'
	ELSE 'Weekend'
    END AS 'day_type'
FROM rental;'''
data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
#
#           return_date  staff_id         last_update month  weekday day_type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53   May        1  Workday
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53   May        1  Workday
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53   May        1  Workday
# 3 2005-06-03 01:43:41         2 2006-02-15 21:30:53   May        1  Workday
# 4 2005-06-02 04:33:21         1 2006-02-15 21:30:53   May        1  Workday

# %% [markdown]
# 3#

# %%
query = 'SELECT * FROM film WHERE title LIKE %s;'
data = pd.read_sql_query(query, engine, params=('%ARMAGEDDON%',))
data.head()
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# 2            1                 None                6         2.99     161
# ...

# %% [markdown]
# 4#

# %%
query = "SELECT * FROM FILM ORDER BY LENGTH DESC;"
data = pd.read_sql_query(query, engine)
data.head(10)
# Out:
#    film_id               title  \
# 0      141       CHICAGO NORTH
# 1      182      CONTROL ANTHEM
# 2      212      DARN FORRESTER
# 3      349         GANGS PRIDE
# 4      426           HOME PITY
# 5      609       MUSCLE BRIGHT
# 6      690        POND SEATTLE
# 7      817  SOLDIERS EVOLUTION
# 8      872   SWEET BROTHERHOOD
# 9      991        WORST BANGER
#
#                                          description  release_year  \
# 0  A Fateful Yarn of a Mad Cow And a Waitress who...          2006
# 1  A Fateful Documentary of a Robot And a Student...          2006
# 2  A Fateful Story of a A Shark And a Explorer wh...          2006
# 3  A Taut Character Study of a Woman And a A Shar...          2006
# 4  A Touching Panorama of a Man And a Secret Agen...          2006
# 5  A Stunning Panorama of a Sumo Wrestler And a H...          2006
# 6  A Stunning Drama of a Teacher And a Boat who m...          2006
# 7  A Lacklusture Panorama of a A Shark And a Pion...          2006
# ...

# %% [markdown]
# 5#

# %%
query = 'SELECT * FROM film WHERE special_features like %s;'
data = pd.read_sql_query(query, engine, params=('%Behind the Scenes%',))
data.head()
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        4  AFFAIR PREJUDICE
# 2       11   ALAMO VIDEOTAPE
# 3       13       ALI FOREVER
# 4       14    ALICE FANTASIA
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 2  A Boring Epistle of a Butler And a Cat who mus...          2006
# 3  A Action-Packed Drama of a Dentist And a Croco...          2006
# 4  A Emotional Drama of a A Shark And a Database ...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                6         0.99      86
# 1            1                 None                5         2.99     117
# 2            1                 None                6         0.99     126
# 3            1                 None                4         4.99     150
# ...

# %% [markdown]
# 6#

# %%
query = "SELECT rating, ROUND(AVG(length),2) 'Mean Length' FROM sakila.film GROUP BY rating;"
data = pd.read_sql_query(query, engine)
data.head()

#Mean Length is more than 2 Hours for PG-13 rated Films.
# Out:
#   rating  Mean Length
# 0     PG       112.01
# 1      G       111.05
# 2  NC-17       113.23
# 3  PG-13       120.44
# 4      R       118.66

# %% [markdown]
# 7#

# %%
query = "SELECT title, length, rating FROM film WHERE length NOT IN ('0') ORDER by length DESC;"
data = pd.read_sql_query(query, engine)
data.head()
# Out:
#             title  length rating
# 0   CHICAGO NORTH     185  PG-13
# 1  CONTROL ANTHEM     185      G
# 2  DARN FORRESTER     185      G
# 3     GANGS PRIDE     185  PG-13
# 4       HOME PITY     185      R
